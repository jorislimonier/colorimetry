# %%
import unidecode
import pandas as pd

# %%
YOB = 1998
MOB = 2
DOB = 12
FIRST_NAME = "JORIS"
LAST_NAME = "LIMONIER"

# %%
date_str = f"{DOB}{MOB}{YOB}"


def reduce_number(date):
    """Convert a number to the iterative sum of its digits"""
    # convert `date` to a string if it isn't already one
    if not isinstance(date, str):
        date = str(date)

    summed_date = 0

    # iterate over digits in `date`
    for digit in date:
        summed_date += int(digit)

    # recursively sum digits until only one is left
    if len(str(summed_date)) > 1:
        return reduce_number(str(summed_date))
    else:
        return summed_date


def plain_upper(letter):
    letter = unidecode.unidecode(letter)  # remove accent

    # convert to uppercase if necessary
    if not letter.isupper():
        letter = letter.upper()

    return letter


def get_letter_rank(letter):
    base_rank = ord("A")
    letter = plain_upper(letter)
    return (ord(letter) - base_rank) % 9 + 1


def name_to_reduced_number(name):
    """Takes a name, converts it to the rank of its letters, then reduces by iteratively summing the obtained digits"""
    number_name = ""

    for letter in name:
        letter_rank = get_letter_rank(letter)
        number_name += str(letter_rank)
    return reduce_number(number_name)

# %%
df = pd.read_excel("colors_meaning.xlsx")
df
# Out:
#    id   color                            title  \
# 0   1   rouge                pionnier /victime
# 1   2  orange                  empereur/martyr
# 2   3   jaune               guerrier/serviteur
# 3   4    vert                jardinier/artiste
# 4   5    bleu  communicateur/enfant silencieux
# 5   6  indigo            magicien/intellectuel
# 6   7  violet                    dictateur/roi
# 7   8    rose                 amoureux/perdant
# 8   9    gold              sage/bouc émissaire
#
#                                             keywords
# 0  dynamique, actif, immédiat, impatient, rapide,...
# 1  tolérant, pacifiste, equilibré, patient, apais...
# 2  intellect, rationnel, penseur, académique, app...
# 3  abondant, croissance, équilibre, immobilité, v...
# 4  communication, confiance, honnêteté, ouvert d'...
# 5  imaginatif, visions, compréhension, discrimina...
# 6  aspiration, connaissance, sagesse, perception,...
# 7  union, soutien, compassion, vision globale, gu...
# 8  enseignement, compassion, compréhension, tolér...
